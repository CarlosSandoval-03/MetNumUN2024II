# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/csandovalcSymPyLab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$

# %% [markdown]
# # Number of operations to compute a polynomial
# ## Extended
# $$ a_5 x^5 + a_4 x^4 + a_3 x^3 + a_2 x^2 + a_1 x + a_0 = a_5*x*x*x*x*x + a_4*x*x*x*x  + a_3*x*x*x + a_2*x*x + a_1*x + a_0$$
#
# $$ 5+4+3+2+1 = \frac{5*6}{2} (*) + 5 (+)  =20 \text{ ops} $$
#
# $$ a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} + \cdots + a_2 x^2 + a_1 x + a_0$$
#
# $$ \frac{n(n+1)}{2} (*) + n (+)  =\frac{n^2}{2} + \frac{3}{2} n\text{ ops} $$

# %% [markdown]
# ## Monomials product
#
# $$(x-r_1)(x-r_2)(x-r_3)(x-r_4)(x-r_5)$$
#
#
# $$ 5 (-) + 4 (*) = 9  \text{ ops} $$
#
# $$(x-r_1)(x-r_2)(x-r_3)\cdots (x-r_{n-1})(x-r_n)$$
#
# $$ n-1 (*) + n (-)  =  2n-1 \text{ ops} $$

# %% [markdown]
# ## Nexted
# $$  ((((a_5 x+ a_4 )x  + a_3) x + a_2)x +a_1)x + a_0 $$
#
# $$ 5 (*) + 5 (+)  = 10 \text{ ops} $$
#
#
# $$ ((((a_n x+ a_{n-1} )x  + a_{n-1}) x + \cdots a_2)x +a_1)x + a_0 $$
#
# $$ n (*) + n (+)  = 2n \text{ ops} $$

# %% [markdown]
# ## **My Own Example**
# Sandoval Id Code = 43. \\
# 43 mod 10 = 3. \\
#
# ### **The custom polynomial**
# - $$(x-3)(x+4)(x-12)(x-1)(x+47)(x+8)(x-71)(x+94)(x-20)(x+11)$$
#
#
# ### **Expanded form of the polynomial**
# $$-79498552320 + 78141288576 x + 9601970272 x^2 - 7589637336 x^3 - 743516194 x^4 + 82837377 x^5 + 5875917 x^6 - 259554 x^7 - 6796 x^8 + 57 x^9 + x^{10}$$
#
#
# ### **Polynomial divided by the root**
# - $$ \frac{(x-3)(x+4)(x-12)(x-1)(x+47)(x+8)(x-71)(x+94)(x-20)(x+11)}{x - 3} $$
#
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_00-18.png?raw=true" />
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_00-20.png?raw=true" />
# </p>

# %%
from sympy import Symbol
from sympy import div
from typing import List


def divPoly(p, roots: List[int]):
    for root in roots:
        p, r = div(p,  x-root)
        print("P:", end="")
        print(p)
        print("r:", end="")
        print(r)
        print("\n")

x = Symbol('x')
p = x**10 + 57 * x**9 - 6796 * x**8 - 259554 * x**7 + 5875917 * x**6 + 82837377 * x**5 - 743516194 * x**4 - 7589637336 * x**3 + 9601970272 * x**2 + 78141288576 * x - 79498552320

roots = [-94, -47, -11, -8, -4, 1, 3, 12, 20, 71]
divPoly(p, roots)
# Out:
# P:x**9 - 37*x**8 - 3318*x**7 + 52338*x**6 + 956145*x**5 - 7040253*x**4 - 81732412*x**3 + 93209392*x**2 + 840287424*x - 845729280
# r:0
#
#
# P:x**8 - 84*x**7 + 630*x**6 + 22728*x**5 - 112071*x**4 - 1772916*x**3 + 1594640*x**2 + 18261312*x - 17994240
# r:0
#
#
# P:x**7 - 95*x**6 + 1675*x**5 + 4303*x**4 - 159404*x**3 - 19472*x**2 + 1808832*x - 1635840
# r:0
#
#
# P:x**6 - 103*x**5 + 2499*x**4 - 15689*x**3 - 33892*x**2 + 251664*x - 204480
# r:0
#
#
# P:x**5 - 107*x**4 + 2927*x**3 - 27397*x**2 + 75696*x - 51120
# r:0
#
#
# P:x**4 - 106*x**3 + 2821*x**2 - 24576*x + 51120
# r:0
#
#
# P:x**3 - 103*x**2 + 2512*x - 17040
# r:0
#
#
# P:x**2 - 91*x + 1420
# r:0
#
#
# P:x - 71
# r:0
#
#
# P:1
# r:0

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_00-28.png?raw=true" />
# </p>

# %%
p = x**10 + 57 * x**9 - 6796 * x**8 - 259554 * x**7 + 5875917 * x**6 + 82837377 * x**5 - 743516194 * x**4 - 7589637336 * x**3 + 9601970272 * x**2 + 78141288576 * x - 79498552320
divPoly(p, [9])
# Out:
# P:x**9 + 66*x**8 - 6202*x**7 - 315372*x**6 + 3037569*x**5 + 110175498*x**4 + 248063288*x**3 - 5357067744*x**2 - 38611639424*x - 269363466240
# r:-2503769748480

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - $$factor(-79498552320 + 78141288576 x + 9601970272 x^2 - 7589637336 x^3 - 743516194 x^4 + 82837377 x^5 + 5875917 x^6 - 259554 x^7 - 6796 x^8 + 57 x^9 + x^{10})$$

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_00-43.png?raw=true" />
# </p>

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 + 57 * x**9 - 6796 * x**8 - 259554 * x**7 + 5875917 * x**6 + 82837377 * x**5 - 743516194 * x**4 - 7589637336 * x**3 + 9601970272 * x**2 + 78141288576 * x - 79498552320)
# Out:
# (x - 71)*(x - 20)*(x - 12)*(x - 3)*(x - 1)*(x + 4)*(x + 8)*(x + 11)*(x + 47)*(x + 94)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
#
# - $$79498552320 + 78141288576 x + 9601970272 x^2 - 7589637336 x^3 - 743516194 x^4 + 82837377 x^5 + 5875917 x^6 - 259554 x^7 - 6796 x^8 + 57 x^9 + x^{10} = 0$$

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_00-51.png?raw=true" />
# </p>

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')

solveset(Eq(x**10 + 57 * x**9 - 6796 * x**8 - 259554 * x**7 + 5875917 * x**6 + 82837377 * x**5 - 743516194 * x**4 - 7589637336 * x**3 + 9601970272 * x**2 + 78141288576 * x - 79498552320, 0), x)
# Out:
# {-94, -47, -11, -8, -4, 1, 3, 12, 20, 71}

# %% [markdown]
# ## Complex
# - $$(15*x^7)*(\sqrt{3} - \pi) - (10*x^5)*(e + \sqrt{2}) + (9*\pi*x^3) - 3*x*(\sqrt{3} + e) + 55558.63$$
#
# - $$(15*x^7)*(\sqrt{3} - pi) - (10*x^5)*(e + sqrt(2)) + (9*pi*x^3) - 3*x*(sqrt(3) + e) + 55558.63 = 0$$

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_01-11.png?raw=true" />
# </p>

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')

p = (15 * x**7) * (sqrt(3) - pi) - (10 * x**5) * (E + sqrt(2)) + (9 * pi * x**3) - 3 * x * (sqrt(3) + E) + 55558.63
solveset(Eq(p, 0), x)
# Out:
# ConditionSet(x, Eq(15*x**7*(-pi + sqrt(3)) - 10*x**5*(sqrt(2) + E) + 9*pi*x**3 - 3*x*(sqrt(3) + E) + 55558.63, 0), Complexes)

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-12.png?raw=true" />
# </p>

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 + 57 * x**9 - 6796 * x**8 - 259554 * x**7 + 5875917 * x**6 + 82837377 * x**5 - 743516194 * x**4 - 7589637336 * x**3 + 9601970272 * x**2 + 78141288576 * x - 79498552320, domain='GF(2)')
# Out:
# x**5*(x + 1)**5

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x * y * z

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-19.png?raw=true" />
# </p>

# %%
from sympy import symbols, I, N, pi, expand

x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = 3 + x1 + I * x2
y = 9 + y1 + I * y2
z = 27 + z1 + I * z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (x1 + I*x2 + 3)*(y1 + I*y2 + 9)*(z1 + I*z2 + 27)
# x1*y1*z1 + I*x1*y1*z2 + 27*x1*y1 + I*x1*y2*z1 - x1*y2*z2 + 27*I*x1*y2 + 9*x1*z1 + 9*I*x1*z2 + 243*x1 + I*x2*y1*z1 - x2*y1*z2 + 27*I*x2*y1 - x2*y2*z1 - I*x2*y2*z2 - 27*x2*y2 + 9*I*x2*z1 - 9*x2*z2 + 243*I*x2 + 3*y1*z1 + 3*I*y1*z2 + 81*y1 + 3*I*y2*z1 - 3*y2*z2 + 81*I*y2 + 27*z1 + 27*I*z2 + 729
# x1*y1*z1 + I*x1*y1*z2 + 27*x1*y1 + I*x1*y2*z1 - x1*y2*z2 + 27*I*x1*y2 + 9*x1*z1 + 9*I*x1*z2 + 243*x1 + I*x2*y1*z1 - x2*y1*z2 + 27*I*x2*y1 - x2*y2*z1 - I*x2*y2*z2 - 27*x2*y2 + 9*I*x2*z1 - 9*x2*z2 + 243*I*x2 + 3*y1*z1 + 3*I*y1*z2 + 81*y1 + 3*I*y2*z1 - 3*y2*z2 + 81*I*y2 + 27*z1 + 27*I*z2 + 729
# x1*y1*z1 + I*x1*y1*z2 + 27*x1*y1 + I*x1*y2*z1 - x1*y2*z2 + 27*I*x1*y2 + 9*x1*z1 + 9*I*x1*z2 + 243*x1 + I*x2*y1*z1 - x2*y1*z2 + 27*I*x2*y1 - x2*y2*z1 - I*x2*y2*z2 - 27*x2*y2 + 9*I*x2*z1 - 9*x2*z2 + 243*I*x2 + 3*y1*z1 + 3*I*y1*z2 + 81*y1 + 3*I*y2*z1 - 3*y2*z2 + 81*I*y2 + 27*z1 + 27*I*z2 + 729
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Bogota in September?
#
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-24.png?raw=true" />
# </p>

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-25.png?raw=true" />
# </p>

# %% [markdown]
# ## SymPy’s integrate
#
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-34.png?raw=true" />
# </p>

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
func = (3 * x**3 + 1201) * sin(x)**3
integral = integrate(func, x)

integral
# Out:
# -3*x**3*sin(x)**2*cos(x) - 2*x**3*cos(x)**3 + 7*x**2*sin(x)**3 + 6*x**2*sin(x)*cos(x)**2 + 14*x*sin(x)**2*cos(x) + 40*x*cos(x)**3/3 - 122*sin(x)**3/9 - 1201*sin(x)**2*cos(x) - 40*sin(x)*cos(x)**2/3 - 2402*cos(x)**3/3

# %% [markdown]
# <p align="center">
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-39.png?raw=true" />
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-39_1.png?raw=true" />
# <img src="https://github.com/CarlosSandoval-03/MetNumUN2024II/blob/main/Lab4/2024-12-08_17-39_2.png?raw=true" />
# </p>

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
func = (3 * x**3 + 1201) * sin(x)**3
integral_definida = integrate(func, (x, 11, 2000))

integral_definida
# Out:
# 3316*cos(11)**3 - 2138*sin(11)*cos(11)**2/3 + 5040*sin(11)**2*cos(11) - 7501*sin(11)**3/9 + 71999960*sin(2000)*cos(2000)**2/3 + 251999878*sin(2000)**3/9 - 15999974134*cos(2000)**3 - 23999973201*sin(2000)**2*cos(2000)

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')

func = (3 * x**3 + 1201) * sin(x)**3
integral_definida = integrate(func, (x, 11, 2000))
N(integral_definida)
# Out:
# 8447624732.54638
